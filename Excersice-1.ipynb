# %%
notebook
# Out:
# UsageError: the following arguments are required: filename

# %%
notebook filename

# %%
notebook
# Out:
# UsageError: the following arguments are required: filename

# %%
pintfoote
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7152/270997398.py in <module>
# ----> 1 pintfoo
#
# NameError: name 'pintfoo' is not defined

# %%
print foo
# Out:
# ------> print(foo)
# ------> print(foo)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7152/806109946.py in <module>
# ----> 1 print(foo)
#
# NameError: name 'foo' is not defined

# %%
print "foo"
# Out:
# ------> print("foo")
# ------> print("foo")
# foo

# %%
pin foo
# Out:
#   File "C:\Users\SajjaD\AppData\Local\Temp/ipykernel_7152/1072397891.py", line 1
#     pin foo
#         ^
# SyntaxError: invalid syntax

# %%
precision
# Out:
# '%r'

# %%
precision 250000
# Out:
# '%.250000f'

# %%
precision 12500
# Out:
# '%.12500f'

# %%
wpd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7152/3834456757.py in <module>
# ----> 1 wpd
#
# NameError: name 'wpd' is not defined

# %%
wpd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7152/3834456757.py in <module>
# ----> 1 wpd
#
# NameError: name 'wpd' is not defined

# %%
wpd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7152/3834456757.py in <module>
# ----> 1 wpd
#
# NameError: name 'wpd' is not defined

# %%
pd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7152/26193472.py in <module>
# ----> 1 pd
#
# NameError: name 'pd' is not defined

# %%
wpind
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7152/1833959308.py in <module>
# ----> 1 wpind
#
# NameError: name 'wpind' is not defined

# %%
wpd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7152/3834456757.py in <module>
# ----> 1 wpd
#
# NameError: name 'wpd' is not defined

# %%
pwd
# Out:
# 'C:\\Users\\SajjaD'

# %%
pylab
# Out:
# <module 'matplotlib.pylab' from 'C:\\Users\\SajjaD\\anaconda3\\lib\\site-packages\\matplotlib\\pylab.py'>

# %%
print("hello world")
# Out:
# hello world

# %%
run
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     701             fpath = None # initialize to make sure fpath is in scope later
# --> 702             fpath = arg_lst[0]
#     703             filename = file_finder(fpath)
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7152/4001939903.py in <module>
# ----> 1 get_ipython().run_line_magic('run', '')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2349                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
# ...

# %%
run print("hello world")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     702             fpath = arg_lst[0]
# --> 703             filename = file_finder(fpath)
#     704         except IndexError:
#
# ~\anaconda3\lib\site-packages\IPython\utils\path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'print("hello.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7152/2377249368.py in <module>
# ----> 1 get_ipython().run_line_magic('run', 'print("hello world")')
#
# ...

# %%
timeit

# %%
~
